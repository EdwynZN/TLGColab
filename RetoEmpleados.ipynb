# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
from sklearn.feature_selection import SelectKBest, f_classif, chi2
from sklearn import linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA

EmpleadosAttrition = pd.read_csv('assets/EmpleadosReto.csv')

# %% [markdown]
# ##### Crea una columna llamada Year y obtén el año de contratación del empleado a partir de su fecha ‘HiringDate’. No se te olvide que debe ser un entero.
# ##### Crea una columna llamada YearsAtCompany que contenga los años que el empleado lleva en la compañía hasta el año 2018. Para su cálculo, usa la variable Year que acabas de crear.

# %%
EmpleadosAttrition['Year'] = EmpleadosAttrition['HiringDate'].str.split('/').str[2].astype(int)
EmpleadosAttrition['YearsAtCompany'] = 2018 - EmpleadosAttrition['Year']

# %% [markdown]
# - La DistanceFromHome está dada en kilómetros, pero tiene las letras “km” al final y así no puede ser entera.
# - Renombra la variable DistanceFromHome a DistanceFromHome_km.
# - Crea una nueva variable DistanceFromHome que sea entera, es decir, solo con números.

# %%
DistanceFromHome_km = EmpleadosAttrition['DistanceFromHome']
EmpleadosAttrition['DistanceFromHome'] = DistanceFromHome_km.str.split(' ').str[0].astype(int)

# %% [markdown]
# #### Borra las columnas Year, HiringDate y DistanceFromHome_km debido a que ya no son útiles.

# %%
EmpleadosAttrition.drop(['Year', 'DistanceFromHome', 'HiringDate'], axis=1, inplace=True);

# %% [markdown]
# Aprovechando los ajustes que se están haciendo, la empresa desea saber si todos los departamentos tienen un ingreso promedio similar. Genera una nuevo frame llamado SueldoPromedioDepto que contenga el MonthlyIncome promedio por departamento de los empleados y colócalo en una variable llamada SueldoPromedio. Esta tabla solo es informativa, no la vas a utilizar en el set de datos que estás construyendo.

# %%
SueldoPromedioDepto = EmpleadosAttrition.groupby(['Department'])[['MonthlyIncome']].mean()

SueldoPromedioDepto.head()
# Out:
#                         MonthlyIncome
# Department
# Human Resources           6239.888889
# Research & Development    6804.149813
# Sales                     7188.250000

# %% [markdown]
# ##### La variable MonthlyIncome tiene un valor numérico muy grande comparada con las otras variables. Escala dicha variable para que tenga un valor entre 0 y 1.

# %%
rangeMonthlyIncome =  EmpleadosAttrition['MonthlyIncome'].max() - EmpleadosAttrition['MonthlyIncome'].min()
EmpleadosAttrition['MonthlyIncome'] = (EmpleadosAttrition['MonthlyIncome'] - EmpleadosAttrition['MonthlyIncome'].min()) / rangeMonthlyIncome

# %% [markdown]
# ##### Elimina las columnas que, con alta probabilidad no tienen relación alguna con la salida usando Fast Correlation-Based Filtering
# ##### Convierte todas las variables categóricas que quedan a numéricas

# %%
data = pd.get_dummies(EmpleadosAttrition, dtype=int)
corr = data.corr()
#corr[:] = np.tril(corr.values, k=-1)

y_1 = corr.loc['Attrition_No', :]
y_2 = corr.loc['Attrition_Yes', :]

lvs = 0.1
lev = 0.9

setValue = set(y_1.loc[y_1.abs() > lvs].index.to_list() + y_2.loc[y_2.abs() > lvs].index.to_list())
setValue.remove('Attrition_No')

removed = set([])
xlist = list(setValue)
for i in range(len(xlist)):
    value = xlist[i]
    for j in range(i, len(xlist)):
        comparator = xlist[j]
        if (comparator == value or j <= i):
            continue
        correlation = abs(corr.at[value, comparator])
        if (correlation >= lev):
            if (abs(corr.at['Attrition_No', comparator]) > abs(corr.at['Attrition_No', value])):
                removed.add(value)
            else:
                removed.add(comparator)

setValue.difference_update(removed)
EmpleadosAttritionFinal = data[list(setValue) + ['Attrition_No', 'Attrition_Yes']]
correlated_map = EmpleadosAttritionFinal.corr()

correlated_map[:] = np.tril(correlated_map.values, k=-1)
correlated_map
# Out:
#                                    MaritalStatus_Divorced  OverTime_No  \
# MaritalStatus_Divorced                           0.000000     0.000000
# OverTime_No                                      0.022216     0.000000
# JobRole_Sales Representative                    -0.072548     0.039372
# YearsInCurrentRole                               0.044210     0.016504
# JobRole_Laboratory Technician                    0.061449     0.029076
# BusinessTravel_Non-Travel                        0.071830     0.065352
# TotalWorkingYears                               -0.005983     0.027569
# JobSatisfaction                                  0.065125     0.030091
# JobRole_Research Director                       -0.013091    -0.007302
# EducationField_Technical Degree                 -0.032866    -0.052395
# JobInvolvement                                  -0.045850    -0.005414
# Age                                             -0.003372     0.055057
# JobLevel                                        -0.018765     0.032124
# JobRole_Healthcare Representative                0.007805     0.013178
# EnvironmentSatisfaction                          0.011568    -0.069882
# MaritalStatus_Single                            -0.348266    -0.041718
# Attrition_Yes                                   -0.107869    -0.324777
# YearsAtCompany                                   0.078852     0.014147
# Attrition_No                                     0.107869     0.324777
# Attrition_Yes                                   -0.107869    -0.324777
#
#                                    JobRole_Sales Representative  \
# MaritalStatus_Divorced                                 0.000000
# OverTime_No                                            0.000000
# JobRole_Sales Representative                           0.000000
# YearsInCurrentRole                                    -0.160339
# JobRole_Laboratory Technician                         -0.115816
# BusinessTravel_Non-Travel                             -0.015232
# TotalWorkingYears                                     -0.238649
# JobSatisfaction                                       -0.072162
# JobRole_Research Director                             -0.081200
# EducationField_Technical Degree                        0.118918
# JobInvolvement                                        -0.001756
# Age                                                   -0.235906
# JobLevel                                              -0.239694
# JobRole_Healthcare Representative                     -0.086066
# EnvironmentSatisfaction                               -0.045226
# MaritalStatus_Single                                   0.162900
# Attrition_Yes                                          0.191294
# YearsAtCompany                                        -0.176251
# Attrition_No                                          -0.191294
# Attrition_Yes                                          0.191294
#
#                                    YearsInCurrentRole  \
# MaritalStatus_Divorced                       0.000000
# OverTime_No                                  0.000000
# JobRole_Sales Representative                 0.000000
# YearsInCurrentRole                           0.000000
# JobRole_Laboratory Technician               -0.122037
# BusinessTravel_Non-Travel                    0.002912
# TotalWorkingYears                            0.429667
# JobSatisfaction                              0.064629
# JobRole_Research Director                    0.221664
# EducationField_Technical Degree              0.054855
# JobInvolvement                              -0.025541
# Age                                          0.130490
# JobLevel                                     0.396268
# JobRole_Healthcare Representative            0.012799
# EnvironmentSatisfaction                     -0.010912
# MaritalStatus_Single                        -0.124278
# Attrition_Yes                               -0.203918
# YearsAtCompany                               0.792964
# Attrition_No                                 0.203918
# Attrition_Yes                               -0.203918
#
#                                    JobRole_Laboratory Technician  \
# MaritalStatus_Divorced                                  0.000000
# OverTime_No                                             0.000000
# JobRole_Sales Representative                            0.000000
# YearsInCurrentRole                                      0.000000
# JobRole_Laboratory Technician                           0.000000
# BusinessTravel_Non-Travel                               0.078258
# TotalWorkingYears                                      -0.225079
# JobSatisfaction                                        -0.036269
# JobRole_Research Director                              -0.141064
# EducationField_Technical Degree                        -0.049482
# JobInvolvement                                          0.019164
# Age                                                    -0.116831
# JobLevel                                               -0.362990
# JobRole_Healthcare Representative                      -0.149518
# EnvironmentSatisfaction                                 0.022702
# MaritalStatus_Single                                   -0.053714
# Attrition_Yes                                           0.125264
# YearsAtCompany                                         -0.120509
# Attrition_No                                           -0.125264
# Attrition_Yes                                           0.125264
#
#                                    BusinessTravel_Non-Travel  \
# MaritalStatus_Divorced                              0.000000
# OverTime_No                                         0.000000
# JobRole_Sales Representative                        0.000000
# YearsInCurrentRole                                  0.000000
# JobRole_Laboratory Technician                       0.000000
# BusinessTravel_Non-Travel                           0.000000
# TotalWorkingYears                                  -0.042652
# JobSatisfaction                                     0.058584
# JobRole_Research Director                          -0.015019
# EducationField_Technical Degree                    -0.042327
# JobInvolvement                                     -0.111339
# Age                                                -0.066922
# JobLevel                                            0.019982
# JobRole_Healthcare Representative                  -0.025283
# EnvironmentSatisfaction                            -0.017601
# MaritalStatus_Single                                0.022163
# Attrition_Yes                                      -0.100698
# YearsAtCompany                                     -0.005409
# Attrition_No                                        0.100698
# Attrition_Yes                                      -0.100698
#
#                                    TotalWorkingYears  JobSatisfaction  \
# MaritalStatus_Divorced                      0.000000         0.000000
# OverTime_No                                 0.000000         0.000000
# JobRole_Sales Representative                0.000000         0.000000
# YearsInCurrentRole                          0.000000         0.000000
# JobRole_Laboratory Technician               0.000000         0.000000
# BusinessTravel_Non-Travel                   0.000000         0.000000
# TotalWorkingYears                           0.000000         0.000000
# JobSatisfaction                            -0.006692         0.000000
# JobRole_Research Director                   0.359642        -0.064142
# EducationField_Technical Degree            -0.050681         0.060854
# JobInvolvement                             -0.029659        -0.028170
# Age                                         0.628271         0.001805
# JobLevel                                    0.753435         0.016500
# JobRole_Healthcare Representative           0.103989         0.015651
# EnvironmentSatisfaction                    -0.033985        -0.005172
# MaritalStatus_Single                       -0.085132        -0.013220
# Attrition_Yes                              -0.213329        -0.164957
# YearsAtCompany                              0.555417         0.037322
# Attrition_No                                0.213329         0.164957
# Attrition_Yes                              -0.213329        -0.164957
#
#                                    JobRole_Research Director  \
# MaritalStatus_Divorced                              0.000000
# OverTime_No                                         0.000000
# JobRole_Sales Representative                        0.000000
# YearsInCurrentRole                                  0.000000
# JobRole_Laboratory Technician                       0.000000
# BusinessTravel_Non-Travel                           0.000000
# TotalWorkingYears                                   0.000000
# JobSatisfaction                                     0.000000
# JobRole_Research Director                           0.000000
# EducationField_Technical Degree                    -0.037551
# JobInvolvement                                      0.015918
# Age                                                 0.196527
# JobLevel                                            0.499024
# JobRole_Healthcare Representative                  -0.104828
# EnvironmentSatisfaction                            -0.049435
# MaritalStatus_Single                               -0.019314
# Attrition_Yes                                      -0.116263
# YearsAtCompany                                      0.224261
# Attrition_No                                        0.116263
# Attrition_Yes                                      -0.116263
#
#                                    EducationField_Technical Degree  \
# MaritalStatus_Divorced                                    0.000000
# OverTime_No                                               0.000000
# JobRole_Sales Representative                              0.000000
# YearsInCurrentRole                                        0.000000
# JobRole_Laboratory Technician                             0.000000
# BusinessTravel_Non-Travel                                 0.000000
# TotalWorkingYears                                         0.000000
# JobSatisfaction                                           0.000000
# JobRole_Research Director                                 0.000000
# EducationField_Technical Degree                           0.000000
# JobInvolvement                                           -0.045780
# Age                                                      -0.078360
# JobLevel                                                 -0.034910
# JobRole_Healthcare Representative                         0.029242
# EnvironmentSatisfaction                                  -0.077323
# MaritalStatus_Single                                     -0.051552
# Attrition_Yes                                             0.129104
# YearsAtCompany                                            0.061173
# Attrition_No                                             -0.129104
# Attrition_Yes                                             0.129104
#
#                                    JobInvolvement       Age  JobLevel  \
# MaritalStatus_Divorced                   0.000000  0.000000  0.000000
# OverTime_No                              0.000000  0.000000  0.000000
# JobRole_Sales Representative             0.000000  0.000000  0.000000
# YearsInCurrentRole                       0.000000  0.000000  0.000000
# JobRole_Laboratory Technician            0.000000  0.000000  0.000000
# BusinessTravel_Non-Travel                0.000000  0.000000  0.000000
# TotalWorkingYears                        0.000000  0.000000  0.000000
# JobSatisfaction                          0.000000  0.000000  0.000000
# JobRole_Research Director                0.000000  0.000000  0.000000
# EducationField_Technical Degree          0.000000  0.000000  0.000000
# JobInvolvement                           0.000000  0.000000  0.000000
# Age                                      0.038652  0.000000  0.000000
# JobLevel                                -0.016726  0.458324  0.000000
# JobRole_Healthcare Representative        0.006799  0.122278  0.085338
# EnvironmentSatisfaction                  0.018475 -0.006172 -0.055742
# MaritalStatus_Single                    -0.061005 -0.108957 -0.054877
# Attrition_Yes                           -0.166785 -0.212121 -0.214266
# YearsAtCompany                          -0.010312  0.186010  0.507820
# Attrition_No                             0.166785  0.212121  0.214266
# Attrition_Yes                           -0.166785 -0.212121 -0.214266
#
#                                    JobRole_Healthcare Representative  \
# MaritalStatus_Divorced                                      0.000000
# OverTime_No                                                 0.000000
# JobRole_Sales Representative                                0.000000
# YearsInCurrentRole                                          0.000000
# JobRole_Laboratory Technician                               0.000000
# BusinessTravel_Non-Travel                                   0.000000
# TotalWorkingYears                                           0.000000
# JobSatisfaction                                             0.000000
# JobRole_Research Director                                   0.000000
# EducationField_Technical Degree                             0.000000
# JobInvolvement                                              0.000000
# Age                                                         0.000000
# JobLevel                                                    0.000000
# JobRole_Healthcare Representative                           0.000000
# EnvironmentSatisfaction                                    -0.037427
# MaritalStatus_Single                                       -0.039083
# Attrition_Yes                                              -0.103274
# YearsAtCompany                                              0.008201
# Attrition_No                                                0.103274
# Attrition_Yes                                              -0.103274
#
#                                    EnvironmentSatisfaction  \
# MaritalStatus_Divorced                            0.000000
# OverTime_No                                       0.000000
# JobRole_Sales Representative                      0.000000
# YearsInCurrentRole                                0.000000
# JobRole_Laboratory Technician                     0.000000
# BusinessTravel_Non-Travel                         0.000000
# TotalWorkingYears                                 0.000000
# JobSatisfaction                                   0.000000
# JobRole_Research Director                         0.000000
# EducationField_Technical Degree                   0.000000
# JobInvolvement                                    0.000000
# Age                                               0.000000
# JobLevel                                          0.000000
# JobRole_Healthcare Representative                 0.000000
# EnvironmentSatisfaction                           0.000000
# MaritalStatus_Single                             -0.014669
# Attrition_Yes                                    -0.124327
# YearsAtCompany                                   -0.013550
# Attrition_No                                      0.124327
# Attrition_Yes                                    -0.124327
#
#                                    MaritalStatus_Single  Attrition_Yes  \
# MaritalStatus_Divorced                         0.000000       0.000000
# OverTime_No                                    0.000000       0.000000
# JobRole_Sales Representative                   0.000000       0.000000
# YearsInCurrentRole                             0.000000       0.000000
# JobRole_Laboratory Technician                  0.000000       0.000000
# BusinessTravel_Non-Travel                      0.000000       0.000000
# TotalWorkingYears                              0.000000       0.000000
# JobSatisfaction                                0.000000       0.000000
# JobRole_Research Director                      0.000000       0.000000
# EducationField_Technical Degree                0.000000       0.000000
# JobInvolvement                                 0.000000       0.000000
# Age                                            0.000000       0.000000
# JobLevel                                       0.000000       0.000000
# JobRole_Healthcare Representative              0.000000       0.000000
# EnvironmentSatisfaction                        0.000000       0.000000
# MaritalStatus_Single                           0.000000       0.000000
# Attrition_Yes                                  0.205849       0.000000
# YearsAtCompany                                -0.126679      -0.176001
# Attrition_No                                  -0.205849      -1.000000
# Attrition_Yes                                  0.205849       1.000000
#
#                                    YearsAtCompany  Attrition_No  Attrition_Yes
# MaritalStatus_Divorced                   0.000000           0.0            0.0
# OverTime_No                              0.000000           0.0            0.0
# JobRole_Sales Representative             0.000000           0.0            0.0
# YearsInCurrentRole                       0.000000           0.0            0.0
# JobRole_Laboratory Technician            0.000000           0.0            0.0
# BusinessTravel_Non-Travel                0.000000           0.0            0.0
# TotalWorkingYears                        0.000000           0.0            0.0
# JobSatisfaction                          0.000000           0.0            0.0
# JobRole_Research Director                0.000000           0.0            0.0
# EducationField_Technical Degree          0.000000           0.0            0.0
# JobInvolvement                           0.000000           0.0            0.0
# Age                                      0.000000           0.0            0.0
# JobLevel                                 0.000000           0.0            0.0
# JobRole_Healthcare Representative        0.000000           0.0            0.0
# EnvironmentSatisfaction                  0.000000           0.0            0.0
# MaritalStatus_Single                     0.000000           0.0            0.0
# Attrition_Yes                            0.000000           0.0            0.0
# YearsAtCompany                           0.000000           0.0            0.0
# Attrition_No                             0.176001           0.0            0.0
# Attrition_Yes                           -0.176001          -1.0            0.0

# %%
data = pd.get_dummies(EmpleadosAttrition[EmpleadosAttrition.columns[~EmpleadosAttrition.columns.isin(['Attrition'])]], dtype=int)
data = pd.concat([data, EmpleadosAttrition['Attrition'].map({'No': 0,'Yes': 1}).to_frame('Attrition')], axis=1)
corr = data.corr()
#corr[:] = np.tril(corr.values, k=-1)

y_1 = corr.loc['Attrition', :]
#y_2 = corr.loc['Attrition_Yes', :]

lvs = 0.1
lev = 0.9

setValue = set(y_1.loc[y_1.abs() > lvs].index.to_list())

removed = set([])
xlist = list(setValue)
for i in range(len(xlist)):
    value = xlist[i]
    for j in range(i, len(xlist)):
        comparator = xlist[j]
        if (comparator == value or j <= i):
            continue
        correlation = abs(corr.at[value, comparator])
        if (correlation >= lev):
            removed.add(value) if (abs(corr.at['Attrition', comparator]) > abs(corr.at['Attrition', value])) else removed.add(comparator)

setValue.difference_update(removed)
EmpleadosAttritionFinal = data[list(setValue)]
correlated_map = EmpleadosAttritionFinal.corr()

correlated_map[:] = np.tril(correlated_map.values, k=-1)
correlated_map
# Out:
#                                    MaritalStatus_Divorced  OverTime_No  \
# MaritalStatus_Divorced                           0.000000     0.000000
# OverTime_No                                      0.022216     0.000000
# JobRole_Sales Representative                    -0.072548     0.039372
# YearsInCurrentRole                               0.044210     0.016504
# JobRole_Laboratory Technician                    0.061449     0.029076
# BusinessTravel_Non-Travel                        0.071830     0.065352
# TotalWorkingYears                               -0.005983     0.027569
# JobSatisfaction                                  0.065125     0.030091
# JobRole_Research Director                       -0.013091    -0.007302
# EducationField_Technical Degree                 -0.032866    -0.052395
# JobInvolvement                                  -0.045850    -0.005414
# Age                                             -0.003372     0.055057
# JobLevel                                        -0.018765     0.032124
# JobRole_Healthcare Representative                0.007805     0.013178
# EnvironmentSatisfaction                          0.011568    -0.069882
# Attrition                                       -0.107869    -0.324777
# MaritalStatus_Single                            -0.348266    -0.041718
# YearsAtCompany                                   0.078852     0.014147
#
#                                    JobRole_Sales Representative  \
# MaritalStatus_Divorced                                 0.000000
# OverTime_No                                            0.000000
# JobRole_Sales Representative                           0.000000
# YearsInCurrentRole                                    -0.160339
# JobRole_Laboratory Technician                         -0.115816
# BusinessTravel_Non-Travel                             -0.015232
# TotalWorkingYears                                     -0.238649
# JobSatisfaction                                       -0.072162
# JobRole_Research Director                             -0.081200
# EducationField_Technical Degree                        0.118918
# JobInvolvement                                        -0.001756
# Age                                                   -0.235906
# JobLevel                                              -0.239694
# JobRole_Healthcare Representative                     -0.086066
# EnvironmentSatisfaction                               -0.045226
# Attrition                                              0.191294
# MaritalStatus_Single                                   0.162900
# YearsAtCompany                                        -0.176251
#
#                                    YearsInCurrentRole  \
# MaritalStatus_Divorced                       0.000000
# OverTime_No                                  0.000000
# JobRole_Sales Representative                 0.000000
# YearsInCurrentRole                           0.000000
# JobRole_Laboratory Technician               -0.122037
# BusinessTravel_Non-Travel                    0.002912
# TotalWorkingYears                            0.429667
# JobSatisfaction                              0.064629
# JobRole_Research Director                    0.221664
# EducationField_Technical Degree              0.054855
# JobInvolvement                              -0.025541
# Age                                          0.130490
# JobLevel                                     0.396268
# JobRole_Healthcare Representative            0.012799
# EnvironmentSatisfaction                     -0.010912
# Attrition                                   -0.203918
# MaritalStatus_Single                        -0.124278
# YearsAtCompany                               0.792964
#
#                                    JobRole_Laboratory Technician  \
# MaritalStatus_Divorced                                  0.000000
# OverTime_No                                             0.000000
# JobRole_Sales Representative                            0.000000
# YearsInCurrentRole                                      0.000000
# JobRole_Laboratory Technician                           0.000000
# BusinessTravel_Non-Travel                               0.078258
# TotalWorkingYears                                      -0.225079
# JobSatisfaction                                        -0.036269
# JobRole_Research Director                              -0.141064
# EducationField_Technical Degree                        -0.049482
# JobInvolvement                                          0.019164
# Age                                                    -0.116831
# JobLevel                                               -0.362990
# JobRole_Healthcare Representative                      -0.149518
# EnvironmentSatisfaction                                 0.022702
# Attrition                                               0.125264
# MaritalStatus_Single                                   -0.053714
# YearsAtCompany                                         -0.120509
#
#                                    BusinessTravel_Non-Travel  \
# MaritalStatus_Divorced                              0.000000
# OverTime_No                                         0.000000
# JobRole_Sales Representative                        0.000000
# YearsInCurrentRole                                  0.000000
# JobRole_Laboratory Technician                       0.000000
# BusinessTravel_Non-Travel                           0.000000
# TotalWorkingYears                                  -0.042652
# JobSatisfaction                                     0.058584
# JobRole_Research Director                          -0.015019
# EducationField_Technical Degree                    -0.042327
# JobInvolvement                                     -0.111339
# Age                                                -0.066922
# JobLevel                                            0.019982
# JobRole_Healthcare Representative                  -0.025283
# EnvironmentSatisfaction                            -0.017601
# Attrition                                          -0.100698
# MaritalStatus_Single                                0.022163
# YearsAtCompany                                     -0.005409
#
#                                    TotalWorkingYears  JobSatisfaction  \
# MaritalStatus_Divorced                      0.000000         0.000000
# OverTime_No                                 0.000000         0.000000
# JobRole_Sales Representative                0.000000         0.000000
# YearsInCurrentRole                          0.000000         0.000000
# JobRole_Laboratory Technician               0.000000         0.000000
# BusinessTravel_Non-Travel                   0.000000         0.000000
# TotalWorkingYears                           0.000000         0.000000
# JobSatisfaction                            -0.006692         0.000000
# JobRole_Research Director                   0.359642        -0.064142
# EducationField_Technical Degree            -0.050681         0.060854
# JobInvolvement                             -0.029659        -0.028170
# Age                                         0.628271         0.001805
# JobLevel                                    0.753435         0.016500
# JobRole_Healthcare Representative           0.103989         0.015651
# EnvironmentSatisfaction                    -0.033985        -0.005172
# Attrition                                  -0.213329        -0.164957
# MaritalStatus_Single                       -0.085132        -0.013220
# YearsAtCompany                              0.555417         0.037322
#
#                                    JobRole_Research Director  \
# MaritalStatus_Divorced                              0.000000
# OverTime_No                                         0.000000
# JobRole_Sales Representative                        0.000000
# YearsInCurrentRole                                  0.000000
# JobRole_Laboratory Technician                       0.000000
# BusinessTravel_Non-Travel                           0.000000
# TotalWorkingYears                                   0.000000
# JobSatisfaction                                     0.000000
# JobRole_Research Director                           0.000000
# EducationField_Technical Degree                    -0.037551
# JobInvolvement                                      0.015918
# Age                                                 0.196527
# JobLevel                                            0.499024
# JobRole_Healthcare Representative                  -0.104828
# EnvironmentSatisfaction                            -0.049435
# Attrition                                          -0.116263
# MaritalStatus_Single                               -0.019314
# YearsAtCompany                                      0.224261
#
#                                    EducationField_Technical Degree  \
# MaritalStatus_Divorced                                    0.000000
# OverTime_No                                               0.000000
# JobRole_Sales Representative                              0.000000
# YearsInCurrentRole                                        0.000000
# JobRole_Laboratory Technician                             0.000000
# BusinessTravel_Non-Travel                                 0.000000
# TotalWorkingYears                                         0.000000
# JobSatisfaction                                           0.000000
# JobRole_Research Director                                 0.000000
# EducationField_Technical Degree                           0.000000
# JobInvolvement                                           -0.045780
# Age                                                      -0.078360
# JobLevel                                                 -0.034910
# JobRole_Healthcare Representative                         0.029242
# EnvironmentSatisfaction                                  -0.077323
# Attrition                                                 0.129104
# MaritalStatus_Single                                     -0.051552
# YearsAtCompany                                            0.061173
#
#                                    JobInvolvement       Age  JobLevel  \
# MaritalStatus_Divorced                   0.000000  0.000000  0.000000
# OverTime_No                              0.000000  0.000000  0.000000
# JobRole_Sales Representative             0.000000  0.000000  0.000000
# YearsInCurrentRole                       0.000000  0.000000  0.000000
# JobRole_Laboratory Technician            0.000000  0.000000  0.000000
# BusinessTravel_Non-Travel                0.000000  0.000000  0.000000
# TotalWorkingYears                        0.000000  0.000000  0.000000
# JobSatisfaction                          0.000000  0.000000  0.000000
# JobRole_Research Director                0.000000  0.000000  0.000000
# EducationField_Technical Degree          0.000000  0.000000  0.000000
# JobInvolvement                           0.000000  0.000000  0.000000
# Age                                      0.038652  0.000000  0.000000
# JobLevel                                -0.016726  0.458324  0.000000
# JobRole_Healthcare Representative        0.006799  0.122278  0.085338
# EnvironmentSatisfaction                  0.018475 -0.006172 -0.055742
# Attrition                               -0.166785 -0.212121 -0.214266
# MaritalStatus_Single                    -0.061005 -0.108957 -0.054877
# YearsAtCompany                          -0.010312  0.186010  0.507820
#
#                                    JobRole_Healthcare Representative  \
# MaritalStatus_Divorced                                      0.000000
# OverTime_No                                                 0.000000
# JobRole_Sales Representative                                0.000000
# YearsInCurrentRole                                          0.000000
# JobRole_Laboratory Technician                               0.000000
# BusinessTravel_Non-Travel                                   0.000000
# TotalWorkingYears                                           0.000000
# JobSatisfaction                                             0.000000
# JobRole_Research Director                                   0.000000
# EducationField_Technical Degree                             0.000000
# JobInvolvement                                              0.000000
# Age                                                         0.000000
# JobLevel                                                    0.000000
# JobRole_Healthcare Representative                           0.000000
# EnvironmentSatisfaction                                    -0.037427
# Attrition                                                  -0.103274
# MaritalStatus_Single                                       -0.039083
# YearsAtCompany                                              0.008201
#
#                                    EnvironmentSatisfaction  Attrition  \
# MaritalStatus_Divorced                            0.000000   0.000000
# OverTime_No                                       0.000000   0.000000
# JobRole_Sales Representative                      0.000000   0.000000
# YearsInCurrentRole                                0.000000   0.000000
# JobRole_Laboratory Technician                     0.000000   0.000000
# BusinessTravel_Non-Travel                         0.000000   0.000000
# TotalWorkingYears                                 0.000000   0.000000
# JobSatisfaction                                   0.000000   0.000000
# JobRole_Research Director                         0.000000   0.000000
# EducationField_Technical Degree                   0.000000   0.000000
# JobInvolvement                                    0.000000   0.000000
# Age                                               0.000000   0.000000
# JobLevel                                          0.000000   0.000000
# JobRole_Healthcare Representative                 0.000000   0.000000
# EnvironmentSatisfaction                           0.000000   0.000000
# Attrition                                        -0.124327   0.000000
# MaritalStatus_Single                             -0.014669   0.205849
# YearsAtCompany                                   -0.013550  -0.176001
#
#                                    MaritalStatus_Single  YearsAtCompany
# MaritalStatus_Divorced                         0.000000             0.0
# OverTime_No                                    0.000000             0.0
# JobRole_Sales Representative                   0.000000             0.0
# YearsInCurrentRole                             0.000000             0.0
# JobRole_Laboratory Technician                  0.000000             0.0
# BusinessTravel_Non-Travel                      0.000000             0.0
# TotalWorkingYears                              0.000000             0.0
# JobSatisfaction                                0.000000             0.0
# JobRole_Research Director                      0.000000             0.0
# EducationField_Technical Degree                0.000000             0.0
# JobInvolvement                                 0.000000             0.0
# Age                                            0.000000             0.0
# JobLevel                                       0.000000             0.0
# JobRole_Healthcare Representative              0.000000             0.0
# EnvironmentSatisfaction                        0.000000             0.0
# Attrition                                      0.000000             0.0
# MaritalStatus_Single                           0.000000             0.0
# YearsAtCompany                                -0.126679             0.0

# %%
x = EmpleadosAttritionFinal[EmpleadosAttritionFinal.columns[~EmpleadosAttritionFinal.columns.isin(['Attrition'])]]
pca = PCA(len(x.columns));

pca.fit(x)
EmpleadosAttritionPCA = pca.explained_variance_ratio_
""" print(f'{pca.explained_variance_ratio_}')
print(f'{pca.transform(x).shape}')
print((x.to_numpy() @ pca.components_[:, :2]).shape)
print(((x - x.mean()) / x.std()).to_numpy() @ pca.components_[:, :2]) """
### los PC principales con el 80% son los primeros 2 componentes con 87%
print(EmpleadosAttritionPCA)
# Out:
# [6.34547220e-01 2.41642359e-01 7.88832142e-02 2.10284923e-02
#  6.51901600e-03 6.41727183e-03 2.87291318e-03 2.79044175e-03
#  1.32533133e-03 1.01147487e-03 6.65785491e-04 6.38068711e-04
#  4.65141321e-04 4.17124285e-04 2.82933160e-04 2.74489426e-04
#  2.18723332e-04]

# %%
EmpleadosAttritionFinal = pd.concat([EmpleadosAttritionFinal, pd.DataFrame(pca.transform(x)[:, :2]).add_prefix('C')], axis=1)

# %%
EmpleadosAttritionFinal.to_csv('assets/EmpleadosAttritionFinal.csv', index=False)
